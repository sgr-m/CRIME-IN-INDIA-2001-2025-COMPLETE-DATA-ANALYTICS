# %% [markdown]
# # FILTERED DATA OVERVIEW

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ## Aggregate Data (2001 - 2023)

# %% [markdown]
# ---

# %% [markdown]
# ### 1. crimes_in_india_2001_2023_filtered

# %%
crimes_in_india_2001_2023_filtered = pd.read_csv('FilteredData/crimes_in_india_2001_2023_filtered.csv')

crimes_in_india_2001_2023_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26690 entries, 0 to 26689
# Data columns (total 39 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           26690 non-null  int64
#  1   state_ut                                             26690 non-null  object
#  2   district                                             26690 non-null  object
#  3   year                                                 26690 non-null  int64
#  4   murder                                               26690 non-null  int64
#  5   attempt_to_murder                                    26690 non-null  int64
#  6   culpable_homicide_not_amounting_to_murder            26690 non-null  int64
#  7   rape                                                 26690 non-null  int64
# ...

# %% [markdown]
# ### 2. crime_state_year.csv

# %%
crime_state_year = pd.read_csv('FilteredData/crime_state_year.csv')
crime_state_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            825 non-null    int64
#  1   state_ut              825 non-null    object
#  2   year                  825 non-null    int64
#  3   voilent_crime_total   825 non-null    int64
#  4   women_crime_total     825 non-null    int64
#  5   property_crime_total  825 non-null    int64
#  6   economic_crime_total  825 non-null    int64
#  7   total_ipc_crimes      825 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 51.7+ KB

# %% [markdown]
# ### 3. crime_district_year.csv

# %%
crime_district_year = pd.read_csv('FilteredData/crime_district_year.csv')
crime_district_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26690 entries, 0 to 26689
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            26690 non-null  int64
#  1   state_ut              26690 non-null  object
#  2   district              26690 non-null  object
#  3   year                  26690 non-null  int64
#  4   voilent_crime_total   26690 non-null  int64
#  5   women_crime_total     26690 non-null  int64
#  6   property_crime_total  26690 non-null  int64
#  7   economic_crime_total  26690 non-null  int64
#  8   total_ipc_crimes      26690 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ### 4. crime_against_women.csv

# %%
crime_against_women = pd.read_csv('FilteredData/crime_against_women.csv')
crime_against_women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26690 entries, 0 to 26689
# Data columns (total 13 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           26690 non-null  int64
#  1   state_ut                                             26690 non-null  object
#  2   district                                             26690 non-null  object
#  3   year                                                 26690 non-null  int64
#  4   rape                                                 26690 non-null  int64
#  5   custodial_rape                                       26690 non-null  int64
#  6   other_rape                                           26690 non-null  int64
#  7   kidnapping_and_abduction_of_women_and_girls          26690 non-null  int64
# ...

# %% [markdown]
# ### 5.  ncrb_state_wise_ipc_summary_2020_2022.csv

# %%
ncrb_state_wise_ipc_summary_2020_2022 = pd.read_csv('FilteredData/ncrb_state_wise_ipc_summary_2020_2022.csv')
ncrb_state_wise_ipc_summary_2020_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                36 non-null     int64
#  1   sl_no                     36 non-null     int64
#  2   state_ut                  36 non-null     object
#  3   crimes_2020               36 non-null     int64
#  4   crimes_2021               36 non-null     int64
#  5   crimes_2022               36 non-null     int64
#  6   population_lakhs_2022     36 non-null     float64
#  7   crime_rate_2022           36 non-null     float64
#  8   chargesheeting_rate_2022  36 non-null     float64
#  9   growth_20_21_pct          36 non-null     float64
#  10  growth_21_22_pct          36 non-null     float64
#  11  avg_crimes_2020_22        36 non-null     float64
#  12  population_million_2022   36 non-null     float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Analysis for the year 2020 - 2024

# %% [markdown]
# ---

# %% [markdown]
# ### 1. weapon_based_crime_2020_2024.csv

# %%
weapon_based_crime_2020_2024 = pd.read_csv('FilteredData/2020_to_2024/weapon_based_crime_2020_2024.csv')
weapon_based_crime_2020_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   7 non-null      int64
#  1   weapon_used  7 non-null      object
#  2   total_cases  7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %% [markdown]
# ### 2. Police_Response_Effectiveness_2020_2024.csv

# %%
Police_Response_Effectiveness_2020_2024 = pd.read_csv('FilteredData/2020_to_2024/Police_Response_Effectiveness_2020_2024.csv')
Police_Response_Effectiveness_2020_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       19 non-null     int64
#  1   police_deployed  19 non-null     int64
#  2   total_cases      19 non-null     int64
#  3   closure_rate     19 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 740.0 bytes

# %% [markdown]
# ### 3. normalized_crime_reports_2020_2024.csv

# %%
normalized_crime_reports_2020_2024 = pd.read_csv('FilteredData/2020_to_2024/normalized_crime_reports_2020_2024.csv')
normalized_crime_reports_2020_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            40160 non-null  int64
#  1   report_number         40160 non-null  int64
#  2   date_reported         40160 non-null  object
#  3   date_of_occurrence    40160 non-null  object
#  4   city                  40160 non-null  object
#  5   crime_domain          40160 non-null  object
#  6   crime_description     40160 non-null  object
#  7   victim_age            40160 non-null  int64
#  8   victim_age_group      40160 non-null  object
#  9   victim_gender         40160 non-null  object
#  10  weapon_used           40160 non-null  object
#  11  police_deployed       40160 non-null  int64
#  12  case_closed_flag      40160 non-null  int64
#  13  case_resolution_days  20062 non-null  float64
# dtypes: float64(1), int64(5), object(8)
# ...

# %% [markdown]
# ### 4. crime_reports_2020_2024.csv

# %%
crime_reports_2020_2024 = pd.read_csv('FilteredData/2020_to_2024/crime_reports_2020_2024.csv')
crime_reports_2020_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            40160 non-null  int64
#  1   report_number         40160 non-null  int64
#  2   date_reported         40160 non-null  object
#  3   date_of_occurrence    40160 non-null  object
#  4   time_of_occurrence    40160 non-null  object
#  5   city                  40160 non-null  object
#  6   crime_code            40160 non-null  int64
#  7   crime_description     40160 non-null  object
#  8   victim_age            40160 non-null  int64
#  9   victim_gender         40160 non-null  object
#  10  weapon_used           40160 non-null  object
#  11  crime_domain          40160 non-null  object
#  12  police_deployed       40160 non-null  int64
#  13  case_closed           40160 non-null  object
#  14  date_case_closed      20062 non-null  object
# ...

# %% [markdown]
# ### 5. crime_against_women_2020_2024.csv

# %%
crime_against_women_2020_2024 = pd.read_csv('FilteredData/2020_to_2024/crime_against_women_2020_2024.csv')
crime_against_women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26690 entries, 0 to 26689
# Data columns (total 13 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           26690 non-null  int64
#  1   state_ut                                             26690 non-null  object
#  2   district                                             26690 non-null  object
#  3   year                                                 26690 non-null  int64
#  4   rape                                                 26690 non-null  int64
#  5   custodial_rape                                       26690 non-null  int64
#  6   other_rape                                           26690 non-null  int64
#  7   kidnapping_and_abduction_of_women_and_girls          26690 non-null  int64
# ...

# %% [markdown]
# ## Analysis for the year 2025

# %% [markdown]
# ### 1. crime_2025_master(combined).csv

# %%
crime_2025_master = pd.read_csv('FilteredData/Year_2025_Month_Wise/crime_2025_master(combined).csv')
crime_2025_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7421 entries, 0 to 7420
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              7421 non-null   int64
#  1   crime_head         7421 non-null   object
#  2   major_head         7421 non-null   object
#  3   minor_head         7421 non-null   object
#  4   ytd_current_year   7421 non-null   int64
#  5   ytd_previous_year  7421 non-null   int64
#  6   previous_month     7421 non-null   int64
#  7   current_month      7421 non-null   int64
#  8   month              7421 non-null   object
#  9   mom_change         7421 non-null   int64
#  10  mom_growth_pct     7421 non-null   float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 637.9+ KB

# %% [markdown]
# ### 2. courts_judge_count_report_2025.csv

# %%
courts_judge_count_report_2025 = pd.read_csv('FilteredData/courts_judge_count_report_2025.csv')
courts_judge_count_report_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   37 non-null     int64
#  1   sr_no                        37 non-null     int64
#  2   state_ut                     37 non-null     object
#  3   working_judges               37 non-null     int64
#  4   incharge_courts              37 non-null     int64
#  5   link_courts                  37 non-null     int64
#  6   total_courts                 37 non-null     int64
#  7   empty_courts                 37 non-null     int64
#  8   invalid_jocode_count         37 non-null     int64
#  9   courts_closed_cases_pending  37 non-null     object
#  10  court_vacancy_rate_pct       36 non-null     float64
#  11  judges_per_court             36 non-null     float64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 3.6+ KB

# %% [markdown]
# ### 3. justice_capacity_in_India_2025.csv

# %%
justice_capacity_in_India_2025 = pd.read_csv('FilteredData/justice_capacity_in_India_2025.csv')
justice_capacity_in_India_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   36 non-null     int64
#  1   sr_no_x                      36 non-null     int64
#  2   state_ut                     36 non-null     object
#  3   working_judges               36 non-null     int64
#  4   incharge_courts              36 non-null     int64
#  5   link_courts                  36 non-null     int64
#  6   total_courts                 36 non-null     int64
#  7   empty_courts                 36 non-null     int64
#  8   invalid_jocode_count         36 non-null     int64
#  9   courts_closed_cases_pending  36 non-null     object
#  10  court_vacancy_rate_pct       36 non-null     float64
#  11  judges_per_court             36 non-null     float64
#  12  sr_no_y                      36 non-null     int64
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## Other Aspects

# %% [markdown]
# ### 1. census_2011_religionwise_population.csv

# %%
census_2011_religionwise_population = pd.read_csv('FilteredData/census_2011_religionwise_population.csv')
census_2011_religionwise_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state_code                 36 non-null     int64
#  1   area_name                  36 non-null     object
#  2   total_persons              36 non-null     int64
#  3   hindu_percent              36 non-null     float64
#  4   muslim_percent             36 non-null     float64
#  5   christian_percent          36 non-null     float64
#  6   sikh_percent               36 non-null     float64
#  7   buddhist_percent           36 non-null     float64
#  8   jain_percent               36 non-null     float64
#  9   others_percent             36 non-null     float64
#  10  no_religion_total_percent  36 non-null     float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ### 2. ruling_party_expanded.csv

# %%
ruling_party_expanded = pd.read_csv('FilteredData/ruling_party_expanded.csv')
ruling_party_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         174 non-null    object
#  1   Year          174 non-null    int64
#  2   Ruling_Party  174 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.2+ KB

# %% [markdown]
# ### 3. State_wise_unemployment_rates_Table_18.1

# %%
state_wise_unemployment = pd.read_csv('FilteredData/State_wise_unemployment_rates_Table_18.1.csv')
state_wise_unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state_ut      37 non-null     object
#  1   rural_male    37 non-null     float64
#  2   rural_female  37 non-null     float64
#  3   rural_person  37 non-null     float64
#  4   urban_male    37 non-null     float64
#  5   urban-female  37 non-null     float64
#  6   urban_person  37 non-null     float64
#  7   total_male    37 non-null     float64
#  8   total_female  37 non-null     float64
#  9   total_person  37 non-null     float64
# dtypes: float64(9), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# ### 4. statewise_census_2011_filtered_data

# %%
statewise_census_2011_filtered_data = pd.read_csv('FilteredData/statewise_census_2011_filtered_data.csv')
statewise_census_2011_filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                34 non-null     object
#  3   Population             35 non-null     object
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     object
#  6   Females                35 non-null     object
#  7   Sex Ratio              35 non-null     object
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(1), object(11)
# ...

# %% [markdown]
# ### 5.District_wise_Literacy_Data_2011

# %%
district_wise_Literacy_Data_2011 = pd.read_csv('FilteredData/District_wise_Literacy_Data_2011.csv')
district_wise_Literacy_Data_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   s_no                 640 non-null    int64
#  1   District             640 non-null    object
#  2   State                640 non-null    object
#  3   Literacy_in_Percent  640 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 20.1+ KB

# %% [markdown]
# #### 6. Literacy_Rate_In_India_(State_wise)_upto_2011_datafile

# %%
statewise_literacy  = pd.read_csv('FilteredData/Literacy_Rate_In_India_(State_wise)_upto_2011_datafile.csv')
statewise_literacy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state_ut                35 non-null     object
#  1   1991 - Male             35 non-null     int64
#  2   1991 - Female           35 non-null     int64
#  3   1991 - Persons          35 non-null     int64
#  4   2001 - Male             35 non-null     int64
#  5   2001 - Female           35 non-null     int64
#  6   2001 - Persons          35 non-null     int64
#  7   2011 - Rural - Male     35 non-null     int64
#  8   2011 - Rural - Female   35 non-null     int64
#  9   2011 - Rural - Person   35 non-null     int64
#  10  2011 - Urban - Male     35 non-null     int64
#  11  2011 - Urban - Female   35 non-null     int64
#  12  2011 - Urban - Persons  35 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 3.7+ KB
