# %% [markdown]
# # MONTH WISE CRIME RECORDS IN INDIA 2025 - DATA ANALYTICS

# %% [markdown]
# #### Source: https://www.data.gov.in/catalog/crime-reveiw-year-2025?page=2

# %% [markdown]
# #### Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os
import datetime
import statistics as stat

# %% [markdown]
# ### Loading: January 2025 datafile.csv

# %%
jan_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/JANUARY 2025 datafile.csv')

jan_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 8 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   SL NO                                                       729 non-null    int64
#  1   HEADS CRIME                                                 729 non-null    object
#  2   MAJOR HEADS                                                 729 non-null    object
#  3   MINOR HEADS                                                 660 non-null    object
#  4   During the current year upto the end of month under review  724 non-null    float64
#  5   During the corresponding month of previous year             724 non-null    float64
#  6   During the previous month                                   724 non-null    float64
# ...

# %% [markdown]
# | Column                            | Meaning                                         |
# | --------------------------------- | ----------------------------------------------- |
# | HEADS CRIME                       | Broad crime category (IPC / SLL / Special Acts) |
# | MAJOR HEADS                       | Major crime classification                      |
# | MINOR HEADS                       | Specific crime types                            |
# | Current year upto end of month    | YTD cumulative (Jan–Apr 2025)                   |
# | Corresponding month previous year | YTD comparison (Jan–Apr 2024)                   |
# | During previous month             | March 2025                                      |
# | During current month              | April 2025                                      |

# %%
jan_2025.head()
# Out:
#    SL NO    HEADS CRIME                           MAJOR HEADS  \
# 0      1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1      2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2      3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3      4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4      5  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                            MINOR HEADS  \
# 0                             For gain
# 1                Over Property Dispute
# 2  Due to Personal Vendetta or enemity
# 3               Due to Sexual jealousy
# 4                 For dowry by burning
#
#    During the current year upto the end of month under review  \
# 0                                                4.0
# 1                                                2.0
# 2                                                2.0
# 3                                                2.0
# 4                                                0.0
#
# ...

# %% [markdown]
# #### A. Rename Columns

# %%
jan = jan_2025.copy()

jan.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %% [markdown]
# #### B. Handle Missing Values

# %%
jan['minor_head'] = jan['minor_head'].fillna('ALL / NOT SPECIFIED')

# %% [markdown]
# ##### For numeric values

# %%
numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

jan[numeric_cols] = jan[numeric_cols].fillna(0)

# %% [markdown]
# ### High-Value Derived Metrics

# %% [markdown]
# #### A. Month-on-Month Growth (%)

# %%
# # growth % = [current month - prev. month] / prev. month] * 100 
# # Shows crime spikes or declines

# jan['mom_growth_pct'] = (
#     (jan['current_month'] - jan['previous_month'])
#     / jan['previous_month'].replace(0, pd.NA)
# ) * 100

# %% [markdown]
# #### B. Year-on-Year Growth (YTD)

# %%
# # year on year growth % = (cy-py /py )*100
# # indicator for policy evaluation

# jan['yoy_ytd_growth_pct'] = (
#     (jan['ytd_current_year'] - jan['ytd_previous_year'])
#     / jan['ytd_previous_year'].replace(0, pd.NA)
# ) * 100

# %% [markdown]
# ### Loading: Feb 2025 datafile.csv

# %%
feb_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/FEB 2025 datafile.csv')

feb_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 8 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   SL.NO.                                                      730 non-null    int64
#  1   HEAD CRIMES                                                 730 non-null    object
#  2   MAJOR HEADS                                                 730 non-null    object
#  3   MINOR HEADS                                                 688 non-null    object
#  4   During the current year upto the end of month under review  725 non-null    float64
#  5   During the corresponding month of previous year             725 non-null    float64
#  6   During the previous month                                   725 non-null    float64
# ...

# %%
feb_2025.head()
# Out:
#    SL.NO.    HEAD CRIMES                           MAJOR HEADS  \
# 0       1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1       2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2       3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3       4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4       5  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                            MINOR HEADS  \
# 0                             For gain
# 1                Over Property Dispute
# 2  Due to Personal Vendetta or enemity
# 3               Due to Sexual jealousy
# 4                 For dowry by burning
#
#    During the current year upto the end of month under review  \
# 0                                                7.0
# 1                                                6.0
# 2                                                7.0
# 3                                                6.0
# 4                                                1.0
#
# ...

# %% [markdown]
# #### Standardize Column Names

# %%
feb = feb_2025.copy()

feb.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %% [markdown]
# #### Clean Missing Values

# %%
feb['minor_head'] = feb['minor_head'].fillna('ALL / NOT SPECIFIED')

numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

feb[numeric_cols] = feb[numeric_cols].fillna(0)

# %% [markdown]
# #### Month Identifier (for joining the data)

# %%
feb['month'] = '2025-02'
jan['month'] = '2025-01'

# %%
# Combine Monthly Datasets 
# monthly_crime = pd.concat(
#     [feb, april],
#     ignore_index=True
# )

# %% [markdown]
# ### Loading: MARCH 2025 datafile.csv

# %%
march_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/MARCH 2025 datafile.csv')

march_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      729 non-null    int64
#  1   Heads of Crime                                              729 non-null    object
#  2   Major Heads                                                 729 non-null    object
#  3   Minor Heads                                                 659 non-null    object
#  4   During the current year upto the end of month under review  729 non-null    int64
#  5   During the corresponding month of previous year             729 non-null    int64
#  6   During the previous month                                   729 non-null    int64
# ...

# %%
march_2025.head()
# Out:
#    Sl.No. Heads of Crime                           Major Heads  \
# 0       1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1       2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2       3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3       4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4       5  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                            Minor Heads  \
# 0                             For gain
# 1                Over Property Dispute
# 2  Due to Personal Vendetta or enemity
# 3               Due to Sexual jealousy
# 4                 For dowry by burning
#
#    During the current year upto the end of month under review  \
# 0                                                  9
# 1                                                  8
# 2                                                  9
# 3                                                  7
# 4                                                  1
#
# ...

# %%
march = march_2025.copy()

# removing garbage column
march = march.drop(columns=['Unnamed: 8'])

# %% [markdown]
# #### B: Rename Column

# %%
# making columns identical for each month: 

march.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %% [markdown]
# #### Handle Missing Values

# %%
march['minor_head'] = march['minor_head'].fillna('ALL / NOT SPECIFIED')

numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

march[numeric_cols] = march[numeric_cols].fillna(0)

# %%
# Month Identifier
march['month'] = '2025-03'

# %% [markdown]
# ### Loading: APRIL 2025 datafile.csv

# %%
april_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/APRIL 2025 datafile.csv')

april_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 8 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl. No.                                                     728 non-null    int64
#  1   Heads of Crime                                              728 non-null    object
#  2   Major Heads                                                 728 non-null    object
#  3   Minor Heads                                                 659 non-null    object
#  4   During the current year upto the end of month under review  728 non-null    int64
#  5   During the corresponding month of previous year             728 non-null    int64
#  6   During the previous month                                   728 non-null    int64
# ...

# %%
april = april_2025.copy()

april.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# Handle Missing Minor Heads
april['minor_head'] = april['minor_head'].fillna('ALL / NOT SPECIFIED')

# %%
# Month Identifier
april['month'] = '2025-04'

# %% [markdown]
# ### Loading: MAY 2025 datafile.csv

# %%
may_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/MAY 2025 datafile.csv')

may_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      732 non-null    int64
#  1   Heads of Crime                                              732 non-null    object
#  2   Major Heads                                                 732 non-null    object
#  3   Minor Heads                                                 681 non-null    object
#  4   During the current year upto the end of month under review  727 non-null    float64
#  5   During the corresponding month of previous year             727 non-null    float64
#  6   During the previous month                                   727 non-null    float64
# ...

# %% [markdown]
# #### Filteration

# %%
may = may_2025.copy()

may = may.drop(columns=['Unnamed: 8'])

# %%
may.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# missing values:

may['minor_head'] = may['minor_head'].fillna('ALL / NOT SPECIFIED')

numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

may[numeric_cols] = may[numeric_cols].fillna(0)

# %%
# datatype change:
may[numeric_cols] = may[numeric_cols].astype(int)

# %%
# month identifier:
may['month'] = '2025-05'

# %% [markdown]
# ### Loading: JUNE 2025 datafile.csv

# %%
june_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/JUNE 2025 datafile.csv')

june_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      737 non-null    int64
#  1   Heads of Crime                                              737 non-null    object
#  2   Major Heads                                                 737 non-null    object
#  3   Minor Heads                                                 675 non-null    object
#  4   During the current year upto the end of month under review  735 non-null    float64
#  5   During the corresponding month of previous year             735 non-null    float64
#  6   During the previous month                                   735 non-null    float64
# ...

# %% [markdown]
# #### Filteration

# %%
# remove column: 
june = june_2025.copy()

june = june.drop(columns=['Unnamed: 8'])

# %%
june.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# missing values:
june['minor_head'] = june['minor_head'].fillna('ALL / NOT SPECIFIED')

numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

june[numeric_cols] = june[numeric_cols].fillna(0)

# %%
# Datatype change:
june[numeric_cols] = june[numeric_cols].astype(int)

# %%
# MONTH identifier
june['month'] = '2025-06'

# %% [markdown]
# ### Loading: JULY 2025 datafile.csv

# %%
july_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/JULY 2025 datafile.csv')

july_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      737 non-null    int64
#  1   Heads of Crime                                              737 non-null    object
#  2   Major Heads                                                 737 non-null    object
#  3   Minor Heads                                                 675 non-null    object
#  4   During the current year upto the end of month under review  735 non-null    float64
#  5   During the corresponding month of previous year             735 non-null    float64
#  6   During the previous month                                   735 non-null    float64
# ...

# %% [markdown]
# #### Filteration

# %%
july = july_2025.copy()

july = july.drop(columns=['Unnamed: 8'])

# %%
july.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# handling missing data:
july['minor_head'] = july['minor_head'].fillna('ALL / NOT SPECIFIED')

numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

july[numeric_cols] = july[numeric_cols].fillna(0)

# %%
# convert Dtype:
july[numeric_cols] = july[numeric_cols].astype(int)

# %%
# month identifier
july['month'] = '2025-07'

# %% [markdown]
# ### Loading: AUGUST 2025 datafile.csv

# %%
aug_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/AUGUST 2025 datafile.csv')

aug_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      764 non-null    int64
#  1   Heads of Crime                                              761 non-null    object
#  2   Major Heads                                                 764 non-null    object
#  3   Minor Heads                                                 691 non-null    object
#  4   During the current year upto the end of month under review  763 non-null    float64
#  5   During the corresponding month of previous year             762 non-null    float64
#  6   During the previous month                                   763 non-null    float64
# ...

# %% [markdown]
# #### Data Filteration

# %%
aug = aug_2025.copy()

aug = aug.drop(columns=['Unnamed: 8'])

# %%
# renaming the columns:
aug.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# handling missing values:
aug['crime_head'] = aug['crime_head'].fillna('TOTAL / NOT SPECIFIED')

# %%
aug['minor_head'] = aug['minor_head'].fillna('ALL / NOT SPECIFIED')

# %%
numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

aug[numeric_cols] = aug[numeric_cols].fillna(0)

# %%
# fix Dtype:
aug[numeric_cols] = aug[numeric_cols].astype(int)

# %%
# month identifier:
aug['month'] = '2025-08'

# %% [markdown]
# ### Loading: SEPTEMBER 2025 datafile.csv

# %%
sept_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/SEPT 2025 datafile.csv')
sept_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      767 non-null    int64
#  1   Heads Crime                                                 767 non-null    object
#  2   Major Heads                                                 767 non-null    object
#  3   Minor Heads                                                 715 non-null    object
#  4   During the current year upto the end of month under review  764 non-null    float64
#  5   During the corresponding month of previous year             764 non-null    float64
#  6   During the previous month                                   764 non-null    float64
# ...

# %% [markdown]
# #### Filteration

# %%
sept = sept_2025.copy()

sept = sept.drop(columns=['Unnamed: 8'])

# %%
#RENAME COLS
sept.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# handling missing values:
sept['minor_head'] = sept['minor_head'].fillna('ALL / NOT SPECIFIED')

# numeric cols filling 
numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

sept[numeric_cols] = sept[numeric_cols].fillna(0)

# %%
sept['minor_head'] = sept['minor_head'].fillna('ALL / NOT SPECIFIED')

# %%
# typecast to INT
sept[numeric_cols] = sept[numeric_cols].astype(int)

# %%
# month tag
sept['month'] = '2025-09'

# %% [markdown]
# ### Loading: OCTOBER 2025 datafile.csv

# %%
oct_2025 = pd.read_csv('Raw Datasets/Crime Datasets/CRIME REVIEW FOR YEAR 2025/OCTOBER 2025 IPC.csv')
oct_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 15 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sl.No.                                                      768 non-null    int64
#  1   Heads of Crime                                              768 non-null    object
#  2   Major Heads                                                 768 non-null    object
#  3   Minor Heads                                                 698 non-null    object
#  4   During the current year upto the end of month under review  765 non-null    float64
#  5   During the corresponding month of previous year             765 non-null    float64
#  6   During the previous month                                   765 non-null    float64
# ...

# %% [markdown]
# #### Data Filteration

# %%
oct_df = oct_2025.copy()

# Removing All Unnamed Columns
oct_df = oct_df.loc[:, ~oct_df.columns.str.contains('^Unnamed')]

# %%
oct_df.columns = [
    'sl_no',
    'crime_head',
    'major_head',
    'minor_head',
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

# %%
# Handle Missing Text Fields
oct_df['minor_head'] = oct_df['minor_head'].fillna('ALL / NOT SPECIFIED')

# %%
# Missing numeric values
numeric_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]

oct_df[numeric_cols] = oct_df[numeric_cols].fillna(0)

# %%
# type conversion
oct_df[numeric_cols] = oct_df[numeric_cols].astype(int)

# %%
# month identifier
oct_df['month'] = '2025-10'

# %% [markdown]
# ### Listing Month-Wise Dataframes

# %%
print(len(jan.columns))
print(len(feb.columns))
print(len(march.columns))
print(len(april.columns))
print(len(may.columns))
print(len(june.columns))
print(len(july.columns))
print(len(aug.columns))
print(len(sept.columns))
print(len(oct_df.columns))
# Out:
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9

# %%
jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              729 non-null    int64
#  1   crime_head         729 non-null    object
#  2   major_head         729 non-null    object
#  3   minor_head         729 non-null    object
#  4   ytd_current_year   729 non-null    float64
#  5   ytd_previous_year  729 non-null    float64
#  6   previous_month     729 non-null    float64
#  7   current_month      729 non-null    float64
#  8   month              729 non-null    object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 51.4+ KB

# %% [markdown]
# ### Concatenating All dataframes

# %%
crime_2025_master = pd.concat(
    [jan, feb, march, april, may, june, july, aug, sept, oct_df],
    ignore_index=True
)

# %%
crime_2025_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7421 entries, 0 to 7420
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              7421 non-null   int64
#  1   crime_head         7421 non-null   object
#  2   major_head         7421 non-null   object
#  3   minor_head         7421 non-null   object
#  4   ytd_current_year   7421 non-null   float64
#  5   ytd_previous_year  7421 non-null   float64
#  6   previous_month     7421 non-null   float64
#  7   current_month      7421 non-null   float64
#  8   month              7421 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 521.9+ KB

# %%
crime_2025_master.head()
# Out:
#    sl_no     crime_head                            major_head  \
# 0      1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1      2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2      3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3      4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4      5  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                             minor_head  ytd_current_year  ytd_previous_year  \
# 0                             For gain               4.0                3.0
# 1                Over Property Dispute               2.0                2.0
# 2  Due to Personal Vendetta or enemity               2.0                1.0
# 3               Due to Sexual jealousy               2.0                1.0
# 4                 For dowry by burning               0.0                0.0
#
#    previous_month  current_month    month
# 0             7.0            4.0  2025-01
# 1             2.0            2.0  2025-01
# ...

# %% [markdown]
# ### B. Final Sanity Checks

# %%
crime_2025_master.info()
crime_2025_master['month'].value_counts().sort_index()
crime_2025_master.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7421 entries, 0 to 7420
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              7421 non-null   int64
#  1   crime_head         7421 non-null   object
#  2   major_head         7421 non-null   object
#  3   minor_head         7421 non-null   object
#  4   ytd_current_year   7421 non-null   float64
#  5   ytd_previous_year  7421 non-null   float64
#  6   previous_month     7421 non-null   float64
#  7   current_month      7421 non-null   float64
#  8   month              7421 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 521.9+ KB
# sl_no                0
# crime_head           0
# major_head           0
# minor_head           0
# ytd_current_year     0
# ytd_previous_year    0
# previous_month       0
# current_month        0
# month                0
# dtype: int64

# %% [markdown]
# ### Fixing Dtype: Global Records

# %%
num_cols = [
    'ytd_current_year',
    'ytd_previous_year',
    'previous_month',
    'current_month'
]
crime_2025_master[num_cols] = crime_2025_master[num_cols].astype(int)

# %% [markdown]
# ### Implementating Statistics

# %% [markdown]
# #### Month-on-Month Change

# %%
# cy-py
crime_2025_master['mom_change'] = (
    crime_2025_master['current_month'] -
    crime_2025_master['previous_month']
)

# %% [markdown]
# #### Growth Rate %

# %%
# Growth = [(cy-py)/py]*100 
crime_2025_master['mom_growth_pct'] = (
    crime_2025_master['mom_change'] /
    crime_2025_master['previous_month'].replace(0, 1)
) * 100

# %% [markdown]
# #### Monthly Crime Trend

# %%
monthly_trend = (
    crime_2025_master.groupby('month')['current_month'].sum().reset_index()
)

# %% [markdown]
# #### Major Head Distribution

# %%
major_head_trend = (
    crime_2025_master.groupby(['month', 'major_head'])['current_month'].sum().reset_index()
)

# %% [markdown]
# #### Export Filtered Data:

# %%
crime_2025_master.to_csv("FilteredData/Year_2025_Month_Wise/crime_2025_master(combined).csv", index=False)
